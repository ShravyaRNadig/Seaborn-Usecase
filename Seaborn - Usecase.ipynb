# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("ToyotaCorolla.csv")
df.head()
# Out:
#    Price  Age     KM FuelType  HP  MetColor  Automatic    CC  Doors  Weight
# 0  13500   23  46986   Diesel  90         1          0  2000      3    1165
# 1  13750   23  72937   Diesel  90         1          0  2000      3    1165
# 2  13950   24  41711   Diesel  90         1          0  2000      3    1165
# 3  14950   26  48000   Diesel  90         0          0  2000      3    1165
# 4  13750   30  38500   Diesel  90         0          0  2000      3    1170

# %%
df.shape
# Out:
# (1436, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
# Price        1436 non-null int64
# Age          1436 non-null int64
# KM           1436 non-null int64
# FuelType     1436 non-null object
# HP           1436 non-null int64
# MetColor     1436 non-null int64
# Automatic    1436 non-null int64
# CC           1436 non-null int64
# Doors        1436 non-null int64
# Weight       1436 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 112.3+ KB

# %% [markdown]
# ## Data Representation

# %%
df["MetColor"]=df["MetColor"].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
# Price        1436 non-null int64
# Age          1436 non-null int64
# KM           1436 non-null int64
# FuelType     1436 non-null object
# HP           1436 non-null int64
# MetColor     1436 non-null object
# Automatic    1436 non-null int64
# CC           1436 non-null int64
# Doors        1436 non-null int64
# Weight       1436 non-null int64
# dtypes: int64(8), object(2)
# memory usage: 112.3+ KB

# %%
df["Automatic"]=df["Automatic"].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
# Price        1436 non-null int64
# Age          1436 non-null int64
# KM           1436 non-null int64
# FuelType     1436 non-null object
# HP           1436 non-null int64
# MetColor     1436 non-null object
# Automatic    1436 non-null object
# CC           1436 non-null int64
# Doors        1436 non-null int64
# Weight       1436 non-null int64
# dtypes: int64(7), object(3)
# memory usage: 112.3+ KB

# %% [markdown]
# ## Checking for Null values

# %%
df.isna().sum() # better use is this
# Out:
# Price        0
# Age          0
# KM           0
# FuelType     0
# HP           0
# MetColor     0
# Automatic    0
# CC           0
# Doors        0
# Weight       0
# dtype: int64

# %%
df.count()
# Out:
# Price        1436
# Age          1436
# KM           1436
# FuelType     1436
# HP           1436
# MetColor     1436
# Automatic    1436
# CC           1436
# Doors        1436
# Weight       1436
# dtype: int64

# %% [markdown]
# ### Decide upon intresting var - Let us say price

# %%
## wht is the type of intresting var? - numrical
sns.distplot(df.Price)
plt.show()

# %%
sns.boxplot(df.Price)
plt.show()

# %% [markdown]
# ### since the distribution is longer in right its right skewed distribution ,right skewed is mean > meadien

# %%
df.Price.mean()
# Out:
# 10730.824512534818

# %%
df1=df[df.Price>10730]
df1.shape
# Out:
# (541, 10)

# %% [markdown]
# ## df1 now hv higherpriced cars

# %%
corr=df.corr()
corr
# corr represent correlation
# Out:
#            Price       Age        KM        HP        CC     Doors    Weight
# Price   1.000000 -0.876590 -0.569960  0.314990  0.165067  0.185326  0.581198
# Age    -0.876590  1.000000  0.505672 -0.156622 -0.133182 -0.148359 -0.470253
# KM     -0.569960  0.505672  1.000000 -0.333538  0.302150 -0.036197 -0.028598
# HP      0.314990 -0.156622 -0.333538  1.000000  0.050884  0.092424  0.089614
# CC      0.165067 -0.133182  0.302150  0.050884  1.000000  0.126768  0.651450
# Doors   0.185326 -0.148359 -0.036197  0.092424  0.126768  1.000000  0.302618
# Weight  0.581198 -0.470253 -0.028598  0.089614  0.651450  0.302618  1.000000

# %%
sns.heatmap(corr)
plt.show()

# %%
sns.heatmap(corr,annot=True)
plt.show()
# as age increses price decreses

# %%
sns.relplot(x="Price",y="Age",data=df)
plt.show()

# %%
sns.relplot(x="Price",y="Age",hue="FuelType",data=df)
plt.show()

# %%
sns.relplot(x="Price",y="Age",hue="Automatic",data=df)
plt.show()

# %%
sns.relplot(x="Price",y="Age",hue="MetColor",data=df)
plt.show()

# %%
sns.relplot(x="Price",y="Age",hue="Price",data=df)
plt.show()

# %%
sns.relplot(x="FuelType",y="Price",data=df)
plt.show()

# %%
sns.catplot(x="FuelType",y="Price",data=df)
plt.show()

# %%
sns.catplot(x="FuelType",y="Price",kind="box",data=df)
plt.show()

# %% [markdown]
# ## Conclusion
# As the age increases, the price of the car drops. It is more true for cars rather than dieselcars. Overpriced vehicles are much sen on the Diesel cars
